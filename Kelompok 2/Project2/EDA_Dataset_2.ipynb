# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
data = pd.read_excel('Processed_Features.xlsx')

# Tampilkan beberapa baris pertama
data.head()
# Out:
#          No       Qty  Harga Satuan  Total Penjualan    Diskon  Tanggal_2-Aug  \
# 0 -1.620185 -0.254801      0.227333        -0.155471 -0.086387      -0.935414
# 1 -1.388730 -1.059434      1.587392        -0.426871 -1.382189      -0.935414
# 2 -1.157275  0.630296     -1.349546        -0.365587  1.209416      -0.935414
# 3 -0.925820 -0.697349     -0.009198        -0.601092 -0.086387       1.069045
# 4 -0.694365  1.475162      0.227333         1.350360  1.209416       1.069045
#
#    Tanggal_3-Aug  Kode Pelanggan_CT-03  Kode Pelanggan_NF-01  \
# 0      -0.707107             -0.603023              1.224745
# 1      -0.707107             -0.603023             -0.816497
# 2      -0.707107              1.658312             -0.816497
# 3      -0.707107              1.658312             -0.816497
# 4      -0.707107             -0.603023             -0.816497
#
#    Nama Pelanggan_Toko Central  Nama Pelanggan_Toko Nofri  Kode Produk_B-10  \
# 0                    -0.603023                   1.224745              -0.5
# 1                    -0.603023                  -0.816497               2.0
# 2                     1.658312                  -0.816497              -0.5
# 3                     1.658312                  -0.816497              -0.5
# 4                    -0.603023                  -0.816497              -0.5
#
#    Kode Produk_P-10  Kode Produk_P-5  Nama Produk_Besi 5 Meter  \
# 0         -0.707107        -0.603023                       2.0
# 1         -0.707107        -0.603023                      -0.5
# 2         -0.707107         1.658312                      -0.5
# 3          1.414214        -0.603023                      -0.5
# 4         -0.707107        -0.603023                       2.0
#
#    Nama Produk_Pipa 10 Meter  Nama Produk_Pipa 5 Meter
# 0                  -0.707107                 -0.603023
# 1                  -0.707107                 -0.603023
# 2                  -0.707107                  1.658312
# 3                   1.414214                 -0.603023
# 4                  -0.707107                 -0.603023

# %%
# Statistik dasar
mean_values = data.mean()
median_values = data.median()
std_dev_values = data.std()

print("Mean:\n", mean_values)
print("\nMedian:\n", median_values)
print("\nStandard Deviation:\n", std_dev_values)
# Out:
# Mean:
#  No                            -2.960595e-17
# Qty                            1.924387e-16
# Harga Satuan                  -1.200429e-16
# Total Penjualan               -1.628327e-16
# Diskon                        -8.696747e-17
# Tanggal_2-Aug                  1.924387e-16
# Tanggal_3-Aug                 -5.921189e-17
# Kode Pelanggan_CT-03           8.881784e-17
# Kode Pelanggan_NF-01          -5.921189e-17
# Nama Pelanggan_Toko Central    8.881784e-17
# Nama Pelanggan_Toko Nofri     -5.921189e-17
# Kode Produk_B-10               4.440892e-17
# Kode Produk_P-10               0.000000e+00
# Kode Produk_P-5                7.401487e-17
# Nama Produk_Besi 5 Meter       4.440892e-17
# Nama Produk_Pipa 10 Meter      0.000000e+00
# Nama Produk_Pipa 5 Meter       7.401487e-17
# dtype: float64
#
# Median:
#  No                             0.000000
# Qty                           -0.254801
# Harga Satuan                  -0.009198
# Total Penjualan               -0.426871
# Diskon                        -0.086387
# Tanggal_2-Aug                 -0.935414
# Tanggal_3-Aug                 -0.707107
# Kode Pelanggan_CT-03          -0.603023
# Kode Pelanggan_NF-01          -0.816497
# Nama Pelanggan_Toko Central   -0.603023
# Nama Pelanggan_Toko Nofri     -0.816497
# Kode Produk_B-10              -0.500000
# Kode Produk_P-10              -0.707107
# Kode Produk_P-5               -0.603023
# Nama Produk_Besi 5 Meter      -0.500000
# Nama Produk_Pipa 10 Meter     -0.707107
# Nama Produk_Pipa 5 Meter      -0.603023
# dtype: float64
#
# Standard Deviation:
#  No                             1.035098
# Qty                            1.035098
# Harga Satuan                   1.035098
# Total Penjualan                1.035098
# Diskon                         1.035098
# Tanggal_2-Aug                  1.035098
# Tanggal_3-Aug                  1.035098
# Kode Pelanggan_CT-03           1.035098
# Kode Pelanggan_NF-01           1.035098
# Nama Pelanggan_Toko Central    1.035098
# Nama Pelanggan_Toko Nofri      1.035098
# Kode Produk_B-10               1.035098
# Kode Produk_P-10               1.035098
# Kode Produk_P-5                1.035098
# Nama Produk_Besi 5 Meter       1.035098
# Nama Produk_Pipa 10 Meter      1.035098
# Nama Produk_Pipa 5 Meter       1.035098
# dtype: float64

# %%
# Histogram
data.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(data['Qty'], data['Total Penjualan'])
plt.title('Scatter Plot Qty vs Total Penjualan')
plt.xlabel('Qty')
plt.ylabel('Total Penjualan')
plt.show()

# %%
# Heatmap Korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap Korelasi')
plt.show()
